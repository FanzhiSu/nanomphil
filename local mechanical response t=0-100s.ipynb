# %%
import numpy as np  
import matplotlib.pyplot as plt

# %%
#data visualisation
data = np.loadtxt('/home/clark/Downloads/test_cases_thesis/a_b_a/calcul.post')
sigma=np.array(data[:,1])# only sigma value for visulisation
epsilon=np.array(data[:,2])# only epsilon value

# %%
plt.plot(epsilon,sigma)
plt.title('a_b_a')
plt.xlabel('eto11')
plt.ylabel('sig11')
# Out:
# Text(0, 0.5, 'sig11')

# %%
#data visualisation
data_2 = np.loadtxt('/home/clark/Downloads/test_cases_thesis/beta_centre/calcul.post')
sigma_2=np.array(data_2[:,1])# only sigma value for visulisation
epsilon_2=np.array(data_2[:,2])# only epsilon value
plt.plot(epsilon_2,sigma_2)
plt.title('beta_centre')
plt.xlabel('eto11')
plt.ylabel('sig11')
# Out:
# Text(0, 0.5, 'sig11')

# %%
#data visualisation
data_3 = np.loadtxt('/home/clark/Downloads/test_cases_thesis/lam1/calcul.post')
sigma_3=np.array(data_3[:,1])# only sigma value for visulisation
epsilon_3=np.array(data_3[:,2])# only epsilon value
plt.plot(epsilon_3,sigma_3)
plt.title('lam1')
plt.xlabel('eto11')
plt.ylabel('sig11')
# Out:
# Text(0, 0.5, 'sig11')

# %%
#data visualisation
data_4 = np.loadtxt('/home/clark/Downloads/test_cases_thesis/lam2/calcul.post')
sigma_4=np.array(data_4[:,1])# only sigma value for visulisation
epsilon_4=np.array(data_4[:,2])# only epsilon value
plt.plot(epsilon_4,sigma_4)
plt.title('lam2')
plt.xlabel('eto11')
plt.ylabel('sig11')
# Out:
# Text(0, 0.5, 'sig11')

# %%
#data visualisation
from matplotlib.pyplot import figure

figure(figsize=(10,10), dpi=80)
data_5 = np.loadtxt('/home/clark/Downloads/test_cases_thesis/lam3/calcul.post')
sigma_5=np.array(data_5[:,1])# only sigma value for visulisation
epsilon_5=np.array(data_5[:,2])# only epsilon value

#plt.plot(epsilon,sigma,label='a_b_a')
plt.plot(epsilon_2, sigma_2,label='beta_centre')
plt.plot(epsilon_3, sigma_3,label='lam1')
plt.plot(epsilon_4, sigma_4,label='lam2')
plt.plot(epsilon_5,sigma_5,label='lam3')

plt.legend()
plt.xlabel('epsilon 11')
plt.ylabel('sigma 11(MPa)')
plt.show()
