# %%
import numpy as np  
import matplotlib.pyplot as plt

# importing pandas module 
mean1=[]
max1=[]
#data visualisation
for i in range(0,1000):
    data1= np.loadtxt('/home/clark/Desktop/mphil/send_structs/struct_1/case'+str(i)+'/c.txt')[:,1]
    a1=(np.mean(data1))*10**6
    a2=(np.max(data1))*10**6
#     b_beta=(np.median(data))*10**6
#     c_beta=(np.max(data))*10**6
#     d_beta=(np.min(data))*10**6
#     e_beta= np.where(data == np.amax(data))
#     max_beta_index.append(e_beta[0])
#     element_beta=divmod(e_beta[0]+1, 8)
#     if element_beta[1]!=0:
#         element_append=element_beta[0]+1
    
#         max_beta_index_element.append(element_append)
#     else:
  
#         max_beta_index_element.append(element_beta[0])

    mean1.append(a1)
    max1.append(a2)
#     median_beta.append(b_beta)
#     max_beta.append(c_beta)
#     min_beta.append(d_beta)
 
#    a=var.append(np.mean(data))


# np.savetxt('beta_max_index.txt',max_beta_index)

# np.savetxt('beta_max_index_in_element.txt',max_beta_index_element,fmt='%s')
# print(max_beta_index_element)

np.savetxt('structure1_mean.txt',mean1)

np.savetxt('structure1_max.txt',max1)

# np.savetxt('beta_median.txt',median_beta)
# np.savetxt('beta_max.txt',max_beta)
# np.savetxt('beta_min.txt',min_beta)
#     data_2= pd.read_csv('lam1.csv')
#     data_3 = pd.read_csv('lam2.csv')
#     data_4 = pd.read_csv('lam3.csv')

# %%
import numpy as np  
import matplotlib.pyplot as plt

# importing pandas module 
mean2=[]
max2=[]
#data visualisation
for i in range(0,1000):
    data2= np.loadtxt('/home/clark/Desktop/mphil/send_structs/struct_2/case'+str(i)+'/c.txt')[:,1]
    a3=(np.mean(data2))*10**6
    a4=(np.max(data2))*10**6
#     b_beta=(np.median(data))*10**6
#     c_beta=(np.max(data))*10**6
#     d_beta=(np.min(data))*10**6
#     e_beta= np.where(data == np.amax(data))
#     max_beta_index.append(e_beta[0])
#     element_beta=divmod(e_beta[0]+1, 8)
#     if element_beta[1]!=0:
#         element_append=element_beta[0]+1
    
#         max_beta_index_element.append(element_append)
#     else:
  
#         max_beta_index_element.append(element_beta[0])

    mean2.append(a3)
    max2.append(a4)
#     median_beta.append(b_beta)
#     max_beta.append(c_beta)
#     min_beta.append(d_beta)
 
#    a=var.append(np.mean(data))


# np.savetxt('beta_max_index.txt',max_beta_index)

# np.savetxt('beta_max_index_in_element.txt',max_beta_index_element,fmt='%s')
# print(max_beta_index_element)

np.savetxt('structure2_mean.txt',mean2)
np.savetxt('structure2_max.txt',max2)
# np.savetxt('beta_median.txt',median_beta)
# np.savetxt('beta_max.txt',max_beta)
# np.savetxt('beta_min.txt',min_beta)
#     data_2= pd.read_csv('lam1.csv')
#     data_3 = pd.read_csv('lam2.csv')
#     data_4 = pd.read_csv('lam3.csv')

# %%
import numpy as np  
import matplotlib.pyplot as plt

# importing pandas module 
mean3=[]
max3=[]
#data visualisation
for i in range(0,1000):
    data3= np.loadtxt('/home/clark/Desktop/mphil/send_structs/struct_3/case'+str(i)+'/c.txt')[:,1]
    a5=(np.mean(data3))*10**6
    a6=(np.max(data3))*10**6
#     b_beta=(np.median(data))*10**6
#     c_beta=(np.max(data))*10**6
#     d_beta=(np.min(data))*10**6
#     e_beta= np.where(data == np.amax(data))
#     max_beta_index.append(e_beta[0])
#     element_beta=divmod(e_beta[0]+1, 8)
#     if element_beta[1]!=0:
#         element_append=element_beta[0]+1
    
#         max_beta_index_element.append(element_append)
#     else:
  
#         max_beta_index_element.append(element_beta[0])

    mean3.append(a5)
    max3.append(a6)
#     median_beta.append(b_beta)
#     max_beta.append(c_beta)
#     min_beta.append(d_beta)
 
#    a=var.append(np.mean(data))


# np.savetxt('beta_max_index.txt',max_beta_index)

# np.savetxt('beta_max_index_in_element.txt',max_beta_index_element,fmt='%s')
# print(max_beta_index_element)

np.savetxt('structure3_mean.txt',mean3)
np.savetxt('structure3_max.txt',max3)
# np.savetxt('beta_median.txt',median_beta)
# np.savetxt('beta_max.txt',max_beta)
# np.savetxt('beta_min.txt',min_beta)
#     data_2= pd.read_csv('lam1.csv')
#     data_3 = pd.read_csv('lam2.csv')
#     data_4 = pd.read_csv('lam3.csv')

3
# Out:
# 3

# %% [markdown]
# # mean

# %%
import matplotlib.pyplot as plt
import scipy.stats
import numpy as np
plt.figure(figsize=[17,18])
# mean,var=scipy.stats.distributions.norm.fit(data)
# mean_2,var_2=scipy.stats.distributions.norm.fit(data_2)
# mean_3,var_3=scipy.stats.distributions.norm.fit(data_3)
# mean_4,var_4=scipy.stats.distributions.norm.fit(data_4)

# x=np.linspace(scipy.stats.norm.ppf(0.01,loc=mean,scale=var),scipy.stats.norm.ppf(0.9999,loc=mean,scale=var),100)
# x_2=np.linspace(scipy.stats.norm.ppf(0.01,loc=mean_2,scale=var_2),scipy.stats.norm.ppf(0.9999,loc=mean_2,scale=var_2),100)
# x_3=np.linspace(scipy.stats.norm.ppf(0.01,loc=mean_3,scale=var_3),scipy.stats.norm.ppf(0.9999,loc=mean_3,scale=var_3),100)
# x_4=np.linspace(scipy.stats.norm.ppf(0.01,loc=mean_4,scale=var_4),scipy.stats.norm.ppf(0.9999,loc=mean_4,scale=var_4),100)
# fitted_data = scipy.stats.distributions.norm.pdf(x, loc=mean, scale=var)
# fitted_data_2 = scipy.stats.distributions.norm.pdf(x_2, loc=mean_2, scale=var_2)
# fitted_data_3 = scipy.stats.distributions.norm.pdf(x_3, loc=mean_3, scale=var_3)
# fitted_data_4 = scipy.stats.distributions.norm.pdf(x_4, loc=mean_4, scale=var_4)

data_5=np.loadtxt('/home/clark/Desktop/mphil/data explore/vertical comparison/beta_mean.txt')
data_6=np.loadtxt('/home/clark/Desktop/mphil/data explore/vertical comparison/lam1_mean.txt')
data_7=np.loadtxt('/home/clark/Desktop/mphil/data explore/vertical comparison/lam2_mean.txt')
data_8=np.loadtxt('/home/clark/Desktop/mphil/data explore/vertical comparison/lam3_mean.txt')
data_ext_1=np.loadtxt('structure1_mean.txt')
data_ext_2=np.loadtxt('structure2_mean.txt')
data_ext_3=np.loadtxt('structure3_mean.txt')

plt.hist(data_5,20, weights=100*(np.ones_like(data_5) / len(data_5)),linewidth=3,stacked=False,color='g',histtype='step',label='shape 1')
plt.hist(data_6,20, weights=100*(np.ones_like(data_6) / len(data_6)),linewidth=3,stacked=False,color='b',histtype='step',label='shape 2')
plt.hist(data_7,20, weights=100*(np.ones_like(data_7) / len(data_7)),linewidth=3,stacked=False,color='r',histtype='step',label='shape 3')
plt.hist(data_8,20, weights=100*(np.ones_like(data_8) / len(data_8)),linewidth=3,stacked=False,color='m',histtype='step',label='shape 4')
plt.hist(data_ext_1,20, weights=100*(np.ones_like(data_ext_1) / len(data_ext_1)),linewidth=3,stacked=False,color='k',histtype='step',label='shape 5')
plt.hist(data_ext_2,20, weights=100*(np.ones_like(data_ext_2) / len(data_ext_2)),linewidth=3,stacked=False,color='y',histtype='step',label='shape 6')
plt.hist(data_ext_3,20, weights=100*(np.ones_like(data_ext_3) / len(data_ext_3)),linewidth=3,stacked=False,color='c',histtype='step',label='shape 7')



plt.xlabel('mean hydrogen concentration / ppm',fontsize=25)
plt.ylabel('probability (%)',fontsize=25)
plt.legend(loc='upper right',prop={'size': 25})

plt.rc('xtick', labelsize=25) 
plt.rc('ytick', labelsize=25) 
plt.savefig('pdf_mean_1000_orientation.png', bbox_inches='tight')
plt.show()

# %%
import numpy as np,matplotlib.pyplot as plt
plt.figure(figsize=[17,18])

def ecdf_(data):
	"""Compute ECDF for a one-dimensional array of measurements."""
    # Number of data points: n
	n = len(data)
    # x-data for the ECDF: x
	x = np.sort(data)
    # y-data for the ECDF: y
	y = np.arange(1,n+1)/n
	return x, y




# Compute ECDFs
x_1,y_1 = ecdf_(data_5/np.linalg.norm(data_5))
x_2,y_2 = ecdf_(data_6/np.linalg.norm(data_6))
x_3,y_3 = ecdf_(data_7/np.linalg.norm(data_7))
x_4,y_4 = ecdf_(data_8/np.linalg.norm(data_8))
x_5,y_5 = ecdf_(data_5)
x_6,y_6 = ecdf_(data_6)
x_7,y_7 = ecdf_(data_7)
x_8,y_8 = ecdf_(data_8)

x_ext_1,y_ext_1=ecdf_(data_ext_1)
x_ext_2,y_ext_2=ecdf_(data_ext_2)
x_ext_3,y_ext_3=ecdf_(data_ext_3)


# # percentiles = np.array([2.5,25,50,75,97.5])
# # ptiles_data1 = np.percentile(x_1,percentiles)
# # ptiles_data2 = np.percentile(x_2,percentiles)
# # ptiles_data3 = np.percentile(x_3,percentiles)
# # ptiles_data4 = np.percentile(x_4,percentiles)


# # ptiles_data5 = np.percentile(x_5,percentiles)
# # ptiles_data6 = np.percentile(x_6,percentiles)
# # ptiles_data7 = np.percentile(x_7,percentiles)
# # ptiles_data8 = np.percentile(x_8,percentiles)



# ###########""bootstrapping
# # def bootstrap(data,num_bootsraps):
# # 	for i in range(num_bootsraps):
# #     	# Generate bootstrap sample: bs_sample
# # 		bs_sample = np.random.choice(data,size=len(data))

# # 	    # Compute and plot ECDF from bootstrap sample
# # 		x, y = ecdf_(bs_sample)
# # 		_ = plt.plot(x, y, marker='.', linestyle='none',color='gray', alpha=0.05)
# ####done



# #bootstrap(data1,500)



# # Plot all ECDFs on the same plot
# plt.plot(x_1,y_1*100,marker='.',linestyle="None",linewidth="9",c="g",label="shape 1")
# plt.plot(x_2,y_2*100,marker='.',linestyle="None",linewidth="9",c="b",label="shape 2")
# plt.plot(x_3,y_3*100,marker='.',linestyle="None",linewidth="9",c="r",label='shape 3')
# plt.plot(x_4,y_4*100,marker='.',linestyle="None",linewidth="9",c="m",label="shape 3")
# # Make nice margins
# plt.margins(0.02)

# # Annotate the plot
# plt.xlabel('normalised mean hydrogen concentration / ppm',fontsize=20)
# _ = plt.ylabel('probability(%)',fontsize=20)

# plt.title('CDF',fontsize=20)
# plt.rc('xtick', labelsize=15) 
# plt.rc('ytick', labelsize=15) 
# # Display the plot

# plt.legend(loc='upper left',prop={'size': 15})

# plt.savefig('cdf_1_mean_1000_orientation.png', bbox_inches='tight')
# plt.show()

# %%
plt.figure(figsize=[17,18])
#_ = plt.plot(ptiles_data, percentiles/100, marker='D', color='red',linestyle='none')#superimposing the percentile as red dotson the graphh
plt.plot(x_5,y_5*100,marker='o',linestyle="None",linewidth="9",color="g",label="shape 1")
plt.plot(x_6,y_6*100,marker='o',linestyle="None",linewidth="9",c="b",label="shape 2")
plt.plot(x_7,y_7*100,marker='o',linestyle="None",linewidth="9",c="r",label="shape 3")
plt.plot(x_8,y_8*100,marker='o',linestyle="None",linewidth="9",c="m",label="shape 4")
plt.plot(x_ext_1,y_ext_1*100,marker='o',linestyle="None",linewidth="9",c="k",label="shape 5")
plt.plot(x_ext_2,y_ext_2*100,marker='o',linestyle="None",linewidth="9",c="y",label="shape 6")
plt.plot(x_ext_3,y_ext_3*100,marker='o',linestyle="None",linewidth="9",c="c",label="shape 7")

# Make nice margins
plt.margins(0.02)

# Annotate the plot
plt.xlabel('mean hydrogen concentration / ppm',fontsize=25)
_ = plt.ylabel('probability(%)',fontsize=25)

# plt.title('CDF',fontsize=20)
plt.rc('xtick', labelsize=25) 
plt.rc('ytick', labelsize=25) 
# Display the plot

plt.legend(loc='upper left',prop={'size': 25})

plt.savefig('cdf_2_mean_1000_orientation.png', bbox_inches='tight')

# %% [markdown]
# # median

# %%
import scipy.stats
plt.figure(figsize=[17,18])
# mean,var=scipy.stats.distributions.norm.fit(data)
# mean_2,var_2=scipy.stats.distributions.norm.fit(data_2)
# mean_3,var_3=scipy.stats.distributions.norm.fit(data_3)
# mean_4,var_4=scipy.stats.distributions.norm.fit(data_4)

# x=np.linspace(scipy.stats.norm.ppf(0.01,loc=mean,scale=var),scipy.stats.norm.ppf(0.9999,loc=mean,scale=var),100)
# x_2=np.linspace(scipy.stats.norm.ppf(0.01,loc=mean_2,scale=var_2),scipy.stats.norm.ppf(0.9999,loc=mean_2,scale=var_2),100)
# x_3=np.linspace(scipy.stats.norm.ppf(0.01,loc=mean_3,scale=var_3),scipy.stats.norm.ppf(0.9999,loc=mean_3,scale=var_3),100)
# x_4=np.linspace(scipy.stats.norm.ppf(0.01,loc=mean_4,scale=var_4),scipy.stats.norm.ppf(0.9999,loc=mean_4,scale=var_4),100)
# fitted_data = scipy.stats.distributions.norm.pdf(x, loc=mean, scale=var)
# fitted_data_2 = scipy.stats.distributions.norm.pdf(x_2, loc=mean_2, scale=var_2)
# fitted_data_3 = scipy.stats.distributions.norm.pdf(x_3, loc=mean_3, scale=var_3)
# fitted_data_4 = scipy.stats.distributions.norm.pdf(x_4, loc=mean_4, scale=var_4)
data_9=np.loadtxt('beta_median.txt')
data_10=np.loadtxt('lam1_median.txt')
data_11=np.loadtxt('lam2_median.txt')
data_12=np.loadtxt('lam3_median.txt')
plt.hist(data_9,20, weights=100*(np.ones_like(data_9) / len(data_9)),linewidth=3,stacked=False,color='g',histtype='step',label='shape 1')
plt.hist(data_10,20, weights=100*(np.ones_like(data_10) / len(data_10)),linewidth=3,stacked=False,color='b',histtype='step',label='shape 2')
plt.hist(data_11,20, weights=100*(np.ones_like(data_11) / len(data_11)),linewidth=3,stacked=False,color='r',histtype='step',label='shape 3')
plt.hist(data_12,20, weights=100*(np.ones_like(data_12) / len(data_12)),linewidth=3,stacked=False,color='m',histtype='step',label='shape 4')




plt.xlabel('median hydrogen concentration / ppm',fontsize=25)
plt.ylabel('probability (%)',fontsize=25)
# plt.title('PDF',fontsize=20)

plt.rc('xtick', labelsize=25) 
plt.rc('ytick', labelsize=25) 
plt.legend(loc='upper right',prop={'size': 25})
plt.savefig('pdf_median_1000_orientation.png', bbox_inches='tight')
plt.show()

# %%
import numpy as np,matplotlib.pyplot as plt
plt.figure(figsize=[17,18])

data_5_cdf=np.loadtxt('beta_median.txt')
data_6_cdf=np.loadtxt('lam1_median.txt')
data_7_cdf=np.loadtxt('lam2_median.txt')
data_8_cdf=np.loadtxt('lam3_median.txt')

def ecdf_(data):
	"""Compute ECDF for a one-dimensional array of measurements."""
    # Number of data points: n
	n = len(data)
    # x-data for the ECDF: x
	x = np.sort(data)
    # y-data for the ECDF: y
	y = np.arange(1,n+1)/n
	return x, y




# Compute ECDFs
x_9,y_9 = ecdf_(data_5_cdf/np.linalg.norm(data_5_cdf))
x_10,y_10 = ecdf_(data_6_cdf/np.linalg.norm(data_6_cdf))
x_11,y_11 = ecdf_(data_7_cdf/np.linalg.norm(data_7_cdf))
x_12,y_12 = ecdf_(data_8_cdf/np.linalg.norm(data_8_cdf))
x_13,y_13 = ecdf_(data_5_cdf)
x_14,y_14= ecdf_(data_6_cdf)
x_15,y_15 = ecdf_(data_7_cdf)
x_16,y_16 = ecdf_(data_8_cdf)




# # percentiles = np.array([2.5,25,50,75,97.5])
# # ptiles_data1 = np.percentile(x_1,percentiles)
# # ptiles_data2 = np.percentile(x_2,percentiles)
# # ptiles_data3 = np.percentile(x_3,percentiles)
# # ptiles_data4 = np.percentile(x_4,percentiles)


# # ptiles_data5 = np.percentile(x_5,percentiles)
# # ptiles_data6 = np.percentile(x_6,percentiles)
# # ptiles_data7 = np.percentile(x_7,percentiles)
# # ptiles_data8 = np.percentile(x_8,percentiles)



# ###########""bootstrapping
# # def bootstrap(data,num_bootsraps):
# # 	for i in range(num_bootsraps):
# #     	# Generate bootstrap sample: bs_sample
# # 		bs_sample = np.random.choice(data,size=len(data))

# # 	    # Compute and plot ECDF from bootstrap sample
# # 		x, y = ecdf_(bs_sample)
# # 		_ = plt.plot(x, y, marker='.', linestyle='none',color='gray', alpha=0.05)
# ####done



# #bootstrap(data1,500)



# # Plot all ECDFs on the same plot
# plt.plot(x_9,y_9*100,marker='.',linestyle="None",linewidth="9",c="g",label="cubic beta ")
# plt.plot(x_10,y_10*100,marker='.',linestyle="None",linewidth="9",c="b",label="cuboidal beta")
# plt.plot(x_11,y_11*100,marker='.',linestyle="None",linewidth="9",c="r",label="2D cross-shaped beta")
# plt.plot(x_12,y_12*100,marker='.',linestyle="None",linewidth="9",c="m",label="3D cross-shaped beta")
# # Make nice margins
# plt.margins(0.02)

# # Annotate the plot
# plt.xlabel('normalised median hydrogen concentration / ppm',fontsize=20)
# _ = plt.ylabel('probability(%)',fontsize=20)

# plt.title('CDF',fontsize=20)
# plt.rc('xtick', labelsize=15) 
# plt.rc('ytick', labelsize=15) 
# # Display the plot

# plt.legend(loc='upper left',prop={'size': 15})

# plt.savefig('cdf_1_median_1000_orientation.png', bbox_inches='tight')
# plt.show()

# %%
plt.figure(figsize=[17,18])
#_ = plt.plot(ptiles_data, percentiles/100, marker='D', color='red',linestyle='none')#superimposing the percentile as red dotson the graphh
plt.plot(x_13,y_13*100,marker='.',linestyle="None",linewidth="9",c="g",label="shape 1")
plt.plot(x_14,y_14*100,marker='.',linestyle="None",linewidth="9",c="b",label="shape 2")
plt.plot(x_15,y_15*100,marker='.',linestyle="None",linewidth="9",c="r",label="shape 3")
plt.plot(x_16,y_16*100,marker='.',linestyle="None",linewidth="9",c="m",label="shape 4")

# Make nice margins
plt.margins(0.02)

# Annotate the plot
plt.xlabel('median hydrogen concentration / ppm',fontsize=25)
_ = plt.ylabel('probability(%)',fontsize=25)

# plt.title('CDF',fontsize=20)
plt.rc('xtick', labelsize=25) 
plt.rc('ytick', labelsize=25) 
# Display the plot

plt.legend(loc='upper left',prop={'size': 25})

plt.rc('xtick', labelsize=25) 
plt.rc('ytick', labelsize=25) 
plt.savefig('cdf_2_median_1000_orientation.png', bbox_inches='tight')

# %% [markdown]
# # min

# %%
import scipy.stats
plt.figure(figsize=[17,18])
# mean,var=scipy.stats.distributions.norm.fit(data)
# mean_2,var_2=scipy.stats.distributions.norm.fit(data_2)
# mean_3,var_3=scipy.stats.distributions.norm.fit(data_3)
# mean_4,var_4=scipy.stats.distributions.norm.fit(data_4)

# x=np.linspace(scipy.stats.norm.ppf(0.01,loc=mean,scale=var),scipy.stats.norm.ppf(0.9999,loc=mean,scale=var),100)
# x_2=np.linspace(scipy.stats.norm.ppf(0.01,loc=mean_2,scale=var_2),scipy.stats.norm.ppf(0.9999,loc=mean_2,scale=var_2),100)
# x_3=np.linspace(scipy.stats.norm.ppf(0.01,loc=mean_3,scale=var_3),scipy.stats.norm.ppf(0.9999,loc=mean_3,scale=var_3),100)
# x_4=np.linspace(scipy.stats.norm.ppf(0.01,loc=mean_4,scale=var_4),scipy.stats.norm.ppf(0.9999,loc=mean_4,scale=var_4),100)
# fitted_data = scipy.stats.distributions.norm.pdf(x, loc=mean, scale=var)
# fitted_data_2 = scipy.stats.distributions.norm.pdf(x_2, loc=mean_2, scale=var_2)
# fitted_data_3 = scipy.stats.distributions.norm.pdf(x_3, loc=mean_3, scale=var_3)
# fitted_data_4 = scipy.stats.distributions.norm.pdf(x_4, loc=mean_4, scale=var_4)
data_13=np.loadtxt('beta_min.txt')
data_14=np.loadtxt('lam1_min.txt')
data_15=np.loadtxt('lam2_min.txt')
data_16=np.loadtxt('lam3_min.txt')
plt.hist(data_13,20, weights=100*(np.ones_like(data_13) / len(data_13)),linewidth=3,stacked=False,color='g',histtype='step',label='shape 1')
plt.hist(data_14,20, weights=100*(np.ones_like(data_14) / len(data_14)),linewidth=3,stacked=False,color='b',histtype='step',label='shape 2')
plt.hist(data_15,20, weights=100*(np.ones_like(data_15) / len(data_15)),linewidth=3,stacked=False,color='r',histtype='step',label='shape 3')
plt.hist(data_16,20, weights=100*(np.ones_like(data_16) / len(data_16)),linewidth=3,stacked=False,color='m',histtype='step',label='shape 4')




plt.xlabel('min hydrogen concentration / ppm',fontsize=25)
plt.ylabel('probability (%)',fontsize=25)
# plt.title('PDF',fontsize=20)
plt.rc('xtick', labelsize=25) 
plt.rc('ytick', labelsize=25) 
plt.legend(loc='upper left',prop={'size': 25})
plt.savefig('pdf_min_1000_orientation.png', bbox_inches='tight')
plt.show()

# %%
import numpy as np,matplotlib.pyplot as plt
plt.figure(figsize=[17,18])

data_9_cdf=np.loadtxt('beta_min.txt')
data_10_cdf=np.loadtxt('lam1_min.txt')
data_11_cdf=np.loadtxt('lam2_min.txt')
data_12_cdf=np.loadtxt('lam3_min.txt')

def ecdf_(data):
	"""Compute ECDF for a one-dimensional array of measurements."""
    # Number of data points: n
	n = len(data)
    # x-data for the ECDF: x
	x = np.sort(data)
    # y-data for the ECDF: y
	y = np.arange(1,n+1)/n
	return x, y




# Compute ECDFs
x_17,y_17 = ecdf_(data_9_cdf/np.linalg.norm(data_9_cdf))
x_18,y_18 = ecdf_(data_10_cdf/np.linalg.norm(data_10_cdf))
x_19,y_19 = ecdf_(data_11_cdf/np.linalg.norm(data_11_cdf))
x_20,y_20 = ecdf_(data_12_cdf/np.linalg.norm(data_12_cdf))
x_21,y_21 = ecdf_(data_9_cdf)
x_22,y_22= ecdf_(data_10_cdf)
x_23,y_23 = ecdf_(data_11_cdf)
x_24,y_24 = ecdf_(data_12_cdf)




# # percentiles = np.array([2.5,25,50,75,97.5])
# # ptiles_data1 = np.percentile(x_1,percentiles)
# # ptiles_data2 = np.percentile(x_2,percentiles)
# # ptiles_data3 = np.percentile(x_3,percentiles)
# # ptiles_data4 = np.percentile(x_4,percentiles)


# # ptiles_data5 = np.percentile(x_5,percentiles)
# # ptiles_data6 = np.percentile(x_6,percentiles)
# # ptiles_data7 = np.percentile(x_7,percentiles)
# # ptiles_data8 = np.percentile(x_8,percentiles)



# ###########""bootstrapping
# # def bootstrap(data,num_bootsraps):
# # 	for i in range(num_bootsraps):
# #     	# Generate bootstrap sample: bs_sample
# # 		bs_sample = np.random.choice(data,size=len(data))

# # 	    # Compute and plot ECDF from bootstrap sample
# # 		x, y = ecdf_(bs_sample)
# # 		_ = plt.plot(x, y, marker='.', linestyle='none',color='gray', alpha=0.05)
# ####done



# #bootstrap(data1,500)



# # Plot all ECDFs on the same plot
# plt.plot(x_17,y_17*100,marker='.',linestyle="None",linewidth="9",c="g",label="cubic beta ")
# plt.plot(x_18,y_18*100,marker='.',linestyle="None",linewidth="9",c="b",label="cuboidal beta")
# plt.plot(x_19,y_19*100,marker='.',linestyle="None",linewidth="9",c="r",label="2D cross-shaped beta")
# plt.plot(x_20,y_20*100,marker='.',linestyle="None",linewidth="9",c="m",label="3D cross-shaped beta")
# # Make nice margins
# plt.margins(0.02)

# # Annotate the plot
# plt.xlabel('normalised min hydrogen concentration / ppm',fontsize=20)
# _ = plt.ylabel('probability(%)',fontsize=20)

# plt.title('CDF',fontsize=20)
# plt.rc('xtick', labelsize=15) 
# plt.rc('ytick', labelsize=15) 
# # Display the plot

# plt.legend(loc='upper left',prop={'size': 15})

# plt.savefig('cdf_1_min_1000_orientation.png', bbox_inches='tight')
# plt.show()

# %%
plt.figure(figsize=[17,18])
#_ = plt.plot(ptiles_data, percentiles/100, marker='D', color='red',linestyle='none')#superimposing the percentile as red dotson the graphh
plt.plot(x_21,y_21*100,marker='.',linestyle="None",linewidth="9",c="g",label="shape 1 ")
plt.plot(x_22,y_22*100,marker='.',linestyle="None",linewidth="9",c="b",label="shape 2")
plt.plot(x_23,y_23*100,marker='.',linestyle="None",linewidth="9",c="r",label="shape 3")
plt.plot(x_24,y_24*100,marker='.',linestyle="None",linewidth="9",c="m",label="shape 4")

# Make nice margins
plt.margins(0.02)

# Annotate the plot
plt.xlabel('min hydrogen concentration / ppm',fontsize=25)
_ = plt.ylabel('probability(%)',fontsize=25)

# plt.title('CDF',fontsize=25)
plt.rc('xtick', labelsize=25) 
plt.rc('ytick', labelsize=25) 
# Display the plot

plt.legend(loc='upper left',prop={'size': 25})

plt.savefig('cdf_2_min_1000_orientation.png', bbox_inches='tight')

# %% [markdown]
# # max

# %%
import scipy.stats
plt.figure(figsize=[17,18])
# mean,var=scipy.stats.distributions.norm.fit(data)
# mean_2,var_2=scipy.stats.distributions.norm.fit(data_2)
# mean_3,var_3=scipy.stats.distributions.norm.fit(data_3)
# mean_4,var_4=scipy.stats.distributions.norm.fit(data_4)

# x=np.linspace(scipy.stats.norm.ppf(0.01,loc=mean,scale=var),scipy.stats.norm.ppf(0.9999,loc=mean,scale=var),100)
# x_2=np.linspace(scipy.stats.norm.ppf(0.01,loc=mean_2,scale=var_2),scipy.stats.norm.ppf(0.9999,loc=mean_2,scale=var_2),100)
# x_3=np.linspace(scipy.stats.norm.ppf(0.01,loc=mean_3,scale=var_3),scipy.stats.norm.ppf(0.9999,loc=mean_3,scale=var_3),100)
# x_4=np.linspace(scipy.stats.norm.ppf(0.01,loc=mean_4,scale=var_4),scipy.stats.norm.ppf(0.9999,loc=mean_4,scale=var_4),100)
# fitted_data = scipy.stats.distributions.norm.pdf(x, loc=mean, scale=var)
# fitted_data_2 = scipy.stats.distributions.norm.pdf(x_2, loc=mean_2, scale=var_2)
# fitted_data_3 = scipy.stats.distributions.norm.pdf(x_3, loc=mean_3, scale=var_3)
# fitted_data_4 = scipy.stats.distributions.norm.pdf(x_4, loc=mean_4, scale=var_4)
data_17=np.loadtxt('/home/clark/Desktop/mphil/data explore/vertical comparison/beta_max.txt')
data_18=np.loadtxt('/home/clark/Desktop/mphil/data explore/vertical comparison/lam1_max.txt')
data_19=np.loadtxt('/home/clark/Desktop/mphil/data explore/vertical comparison/lam2_max.txt')
data_20=np.loadtxt('/home/clark/Desktop/mphil/data explore/vertical comparison/lam3_max.txt')
data_21=np.loadtxt('structure1_max.txt')
data_22=np.loadtxt('structure2_max.txt')
data_23=np.loadtxt('structure3_max.txt')
plt.hist(data_17,20, weights=100*(np.ones_like(data_17) / len(data_17)),linewidth=3,stacked=False,color='g',histtype='step',label='shape 1')
plt.hist(data_18,20, weights=100*(np.ones_like(data_18) / len(data_18)),linewidth=3,stacked=False,color='b',histtype='step',label='shape 2')
plt.hist(data_19,20, weights=100*(np.ones_like(data_19) / len(data_19)),linewidth=3,stacked=False,color='r',histtype='step',label='shape 3')
plt.hist(data_20,20, weights=100*(np.ones_like(data_20) / len(data_20)),linewidth=3,stacked=False,color='m',histtype='step',label='shape 4')
plt.hist(data_21,20, weights=100*(np.ones_like(data_21) / len(data_21)),linewidth=3,stacked=False,color='k',histtype='step',label='shape 5')
plt.hist(data_22,20, weights=100*(np.ones_like(data_22) / len(data_22)),linewidth=3,stacked=False,color='y',histtype='step',label='shape 6')
plt.hist(data_23,20, weights=100*(np.ones_like(data_23) / len(data_23)),linewidth=3,stacked=False,color='c',histtype='step',label='shape 7')

plt.xlabel('max hydrogen concentration / ppm',fontsize=25)
plt.ylabel('probability (%)',fontsize=25)
# plt.title('PDF',fontsize=25)
plt.rc('xtick', labelsize=25) 
plt.rc('ytick', labelsize=25) 
plt.legend(loc='upper right',prop={'size': 25})
plt.savefig('pdf_max_1000_orientation.png', bbox_inches='tight')
plt.show()

# %%
import numpy as np,matplotlib.pyplot as plt
plt.figure(figsize=[17,18])
# data_13_cdf=np.loadtxt('beta_max.txt')
# data_14_cdf=np.loadtxt('lam1_max.txt')
# data_15_cdf=np.loadtxt('lam2_max.txt')
# data_16_cdf=np.loadtxt('lam3_max.txt')

def ecdf_(data):
	"""Compute ECDF for a one-dimensional array of measurements."""
    # Number of data points: n
	n = len(data)
    # x-data for the ECDF: x
	x = np.sort(data)
    # y-data for the ECDF: y
	y = np.arange(1,n+1)/n
	return x, y




# Compute ECDFs
# x_25,y_25 = ecdf_(data_13_cdf/np.linalg.norm(data_13_cdf))
# x_26,y_26 = ecdf_(data_14_cdf/np.linalg.norm(data_14_cdf))
# x_27,y_27 = ecdf_(data_15_cdf/np.linalg.norm(data_15_cdf))
# x_28,y_28 = ecdf_(data_16_cdf/np.linalg.norm(data_16_cdf))
x_29,y_29 = ecdf_(data_17)
x_30,y_30= ecdf_(data_18)
x_31,y_31 = ecdf_(data_19)
x_32,y_32 = ecdf_(data_20)
x_33,y_33 = ecdf_(data_21)
x_34,y_34 = ecdf_(data_22)
x_35,y_35 = ecdf_(data_23)

# # percentiles = np.array([2.5,25,50,75,97.5])
# # ptiles_data1 = np.percentile(x_1,percentiles)
# # ptiles_data2 = np.percentile(x_2,percentiles)
# # ptiles_data3 = np.percentile(x_3,percentiles)
# # ptiles_data4 = np.percentile(x_4,percentiles)


# # ptiles_data5 = np.percentile(x_5,percentiles)
# # ptiles_data6 = np.percentile(x_6,percentiles)
# # ptiles_data7 = np.percentile(x_7,percentiles)
# # ptiles_data8 = np.percentile(x_8,percentiles)



# ###########""bootstrapping
# # def bootstrap(data,num_bootsraps):
# # 	for i in range(num_bootsraps):
# #     	# Generate bootstrap sample: bs_sample
# # 		bs_sample = np.random.choice(data,size=len(data))

# # 	    # Compute and plot ECDF from bootstrap sample
# # 		x, y = ecdf_(bs_sample)
# # 		_ = plt.plot(x, y, marker='.', linestyle='none',color='gray', alpha=0.05)
# ####done



# #bootstrap(data1,500)



# # Plot all ECDFs on the same plot
# plt.plot(x_25,y_25*100,marker='.',linestyle="None",linewidth="9",c="g",label="cubic beta ")
# plt.plot(x_26,y_26*100,marker='.',linestyle="None",linewidth="9",c="b",label="cuboidal beta")
# plt.plot(x_27,y_27*100,marker='.',linestyle="None",linewidth="9",c="r",label="2D cross-shaped beta")
# plt.plot(x_28,y_28*100,marker='.',linestyle="None",linewidth="9",c="m",label="3D cross-shaped beta")
# # Make nice margins
# plt.margins(0.02)

# # Annotate the plot
# plt.xlabel('normalised max hydrogen concentration / ppm',fontsize=20)
# _ = plt.ylabel('probability(%)',fontsize=20)

# plt.title('CDF',fontsize=20)
# plt.rc('xtick', labelsize=15) 
# plt.rc('ytick', labelsize=15) 
# # Display the plot

# plt.legend(loc='upper left',prop={'size': 15})

# plt.savefig('cdf_1_max_1000_orientation.png', bbox_inches='tight')
# plt.show()

# %%
plt.figure(figsize=[17,18])
#_ = plt.plot(ptiles_data, percentiles/100, marker='D', color='red',linestyle='none')#superimposing the percentile as red dotson the graphh
plt.plot(x_29,y_29*100,marker='.',linestyle="None",linewidth="9",c="g",label="shape 1")
plt.plot(x_30,y_30*100,marker='.',linestyle="None",linewidth="9",c="b",label="shape 2")
plt.plot(x_31,y_31*100,marker='.',linestyle="None",linewidth="9",c="r",label="shape 3")
plt.plot(x_32,y_32*100,marker='.',linestyle="None",linewidth="9",c="m",label="shape 4")
plt.plot(x_33,y_33*100,marker='.',linestyle="None",linewidth="9",c="k",label="shape 5")
plt.plot(x_34,y_34*100,marker='.',linestyle="None",linewidth="9",c="y",label="shape 6")
plt.plot(x_35,y_35*100,marker='.',linestyle="None",linewidth="9",c="c",label="shape 7")

# Make nice margins
plt.margins(0.02)

# Annotate the plot
plt.xlabel('max hydrogen concentration / ppm',fontsize=25)
_ = plt.ylabel('probability(%)',fontsize=25)

# plt.title('CDF',fontsize=20)
plt.rc('xtick', labelsize=25) 
plt.rc('ytick', labelsize=25) 
# Display the plot

plt.legend(loc='upper left',prop={'size': 25})

plt.savefig('cdf_2_max_1000_orientation.png', bbox_inches='tight')

# %%
import numpy as np  
import matplotlib.pyplot as plt

# importing pandas module 
import pandas as pd 

#data visualisation
data_mean= pd.read_csv('beta_mean.txt',header=None)
data_2_mean= pd.read_csv('lam1_mean.txt',header=None)
data_3_mean = pd.read_csv('lam2_mean.txt',header=None)
data_4_mean=pd.read_csv('lam3_mean.txt',header=None)

# %%
data_mean=data_mean.rename(columns={0:'cubic beta mean'})
data_2_mean=data_2_mean.rename(columns={0:'cuboidal beta mean'})
data_3_mean=data_3_mean.rename(columns={0:'2D cross-shaped beta mean'})
data_4_mean=data_4_mean.rename(columns={0:'3D cross-shaped beta mean'})
df_mean=pd.concat([data_mean,data_2_mean,data_3_mean,data_4_mean],axis=1,join='inner')

# %%
df_des_mean=df_mean.describe()

df_des_mean
# Out:
#        cubic beta mean  cuboidal beta mean  2D cross-shaped beta mean  \
# count      1000.000000         1000.000000                1000.000000
# mean          1.375564            1.370889                   1.372777
# std           0.005748            0.005875                   0.005827
# min           1.359079            1.354409                   1.356193
# 25%           1.371632            1.366952                   1.368837
# 50%           1.375301            1.370629                   1.372562
# 75%           1.379309            1.374684                   1.376526
# max           1.395974            1.391310                   1.393178
#
#        3D cross-shaped beta mean
# count                1000.000000
# mean                    1.374666
# std                     0.005781
# min                     1.357998
# 25%                     1.370678
# 50%                     1.374402
# 75%                     1.378369
# max                     1.394994

# %%
data_mean= pd.read_csv('beta_mean.txt',header=None)
data_2_mean= pd.read_csv('lam1_mean.txt',header=None)
data_3_mean = pd.read_csv('lam2_mean.txt',header=None)
data_4_mean=pd.read_csv('lam3_mean.txt',header=None)

data_mean=data_mean.rename(columns={0:'shape 1'})
data_2_mean=data_2_mean.rename(columns={0:'shape 2'})
data_3_mean=data_3_mean.rename(columns={0:'shape 3'})
data_4_mean=data_4_mean.rename(columns={0:'shape 4'})
df_mean=pd.concat([data_mean,data_2_mean,data_3_mean,data_4_mean],axis=1,join='inner')
plt.figure(figsize=[17,18])
df_mean.boxplot(return_type='axes',fontsize=25)
plt.ylabel('mean hydrogen concentration / ppm',fontsize=25)
plt.rc('xtick', labelsize=25) 
plt.rc('ytick', labelsize=25) 
plt.savefig('mean_boxplot.png', bbox_inches='tight')

# %%
import numpy as np  
import matplotlib.pyplot as plt

# importing pandas module 
import pandas as pd 

#data visualisation
data_median= pd.read_csv('beta_median.txt',header=None)
data_2_median= pd.read_csv('lam1_median.txt',header=None)
data_3_median = pd.read_csv('lam2_median.txt',header=None)
data_4_median=pd.read_csv('lam3_median.txt',header=None)

data_median=data_median.rename(columns={0:'shape 1'})
data_2_median=data_2_median.rename(columns={0:'shape 2'})
data_3_median=data_3_median.rename(columns={0:'shape 3'})
data_4_median=data_4_median.rename(columns={0:'shape 4'})
df_median=pd.concat([data_median,data_2_median,data_3_median,data_4_median],axis=1,join='inner')

df_des_median=df_median.describe()
df_des_median
# Out:
#            shape 1      shape 2      shape 3      shape 4
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean      1.369166     1.365159     1.366628     1.368254
# std       0.007706     0.008003     0.007888     0.007776
# min       1.344049     1.339524     1.341457     1.343799
# 25%       1.364062     1.360015     1.361364     1.363076
# 50%       1.369138     1.365267     1.366674     1.368298
# 75%       1.373953     1.370178     1.371386     1.372994
# max       1.399102     1.395268     1.397318     1.398094

# %%
data_median= pd.read_csv('beta_median.txt',header=None)
data_2_median= pd.read_csv('lam1_median.txt',header=None)
data_3_median = pd.read_csv('lam2_median.txt',header=None)
data_4_median=pd.read_csv('lam3_median.txt',header=None)

data_median=data_median.rename(columns={0:'shape 1'})
data_2_median=data_2_median.rename(columns={0:'shape 2'})
data_3_median=data_3_median.rename(columns={0:'shape 3'})
data_4_median=data_4_median.rename(columns={0:'shape 4'})
df_median=pd.concat([data_median,data_2_median,data_3_median,data_4_median],axis=1,join='inner')
plt.figure(figsize=[17,18])
df_median.boxplot(return_type='axes',fontsize=20)
plt.ylabel('median hydrogen concentration / ppm',fontsize=25)
plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20) 
plt.savefig('medium_boxplot.png', bbox_inches='tight')

# %%
import numpy as np  
import matplotlib.pyplot as plt

# importing pandas module 
import pandas as pd 

#data visualisation
data_min= pd.read_csv('beta_min.txt',header=None)
data_2_min= pd.read_csv('lam1_min.txt',header=None)
data_3_min = pd.read_csv('lam2_min.txt',header=None)
data_4_min=pd.read_csv('lam3_min.txt',header=None)

data_min=data_min.rename(columns={0:'cubic beta min'})
data_2_min=data_2_min.rename(columns={0:'cuboidal beta min'})
data_3_min=data_3_min.rename(columns={0:'2D cross-shaped beta min'})
data_4_min=data_4_min.rename(columns={0:'3D cross-shaped beta min'})
df_min=pd.concat([data_min,data_2_min,data_3_min,data_4_min],axis=1,join='inner')

df_des_min=df_min.describe()
df_des_min
# Out:
#        cubic beta min  cuboidal beta min  2D cross-shaped beta min  \
# count     1000.000000        1000.000000               1000.000000
# mean         1.057411           1.061743                  1.061427
# std          0.062159           0.064621                  0.063786
# min          0.808031           0.803201                  0.797716
# 25%          1.021963           1.023123                  1.022587
# 50%          1.064818           1.069923                  1.070483
# 75%          1.099526           1.106511                  1.105263
# max          1.205819           1.211483                  1.209721
#
#        3D cross-shaped beta min
# count               1000.000000
# mean                   1.059134
# std                    0.062193
# min                    0.803716
# 25%                    1.023655
# 50%                    1.067644
# 75%                    1.101426
# max                    1.209487

# %%
#data visualisation
data_min= pd.read_csv('beta_min.txt',header=None)
data_2_min= pd.read_csv('lam1_min.txt',header=None)
data_3_min = pd.read_csv('lam2_min.txt',header=None)
data_4_min=pd.read_csv('lam3_min.txt',header=None)

data_min=data_min.rename(columns={0:'cubic beta'})
data_2_min=data_2_min.rename(columns={0:'cuboidal beta'})
data_3_min=data_3_min.rename(columns={0:'2D cross-shaped beta'})
data_4_min=data_4_min.rename(columns={0:'3D cross-shaped beta'})
df_min=pd.concat([data_min,data_2_min,data_3_min,data_4_min],axis=1,join='inner')

plt.figure(figsize=[17,18])
df_min.boxplot(return_type='axes',fontsize=20)
plt.ylabel('min hydrogen concentration / ppm',fontsize=25)
plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20) 
plt.savefig('min_boxplot.png', bbox_inches='tight')

# %%
import numpy as np  
import matplotlib.pyplot as plt

# importing pandas module 
import pandas as pd 

#data visualisation
data_max= pd.read_csv('beta_max.txt',header=None)
data_2_max= pd.read_csv('lam1_max.txt',header=None)
data_3_max = pd.read_csv('lam2_max.txt',header=None)
data_4_max=pd.read_csv('lam3_max.txt',header=None)

data_max=data_max.rename(columns={0:'shape 1 max'})
data_2_max=data_2_max.rename(columns={0:'shape 2 max'})
data_3_max=data_3_max.rename(columns={0:'shape 3 max'})
data_4_max=data_4_max.rename(columns={0:'shape 4 max'})
df_max=pd.concat([data_max,data_2_max,data_3_max,data_4_max],axis=1,join='inner')

df_des_max=df_max.describe()
df_des_max
# Out:
#        shape 1 max  shape 2 max  shape 3 max  shape 4 max
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean      1.840627     1.844369     1.847405     1.858314
# std       0.096642     0.110243     0.103933     0.106113
# min       1.595303     1.589232     1.591130     1.591885
# 25%       1.774289     1.767748     1.775025     1.784477
# 50%       1.827753     1.829303     1.835289     1.840816
# 75%       1.894448     1.902306     1.906355     1.918748
# max       2.262015     2.414251     2.354600     2.375375

# %%
data_max= pd.read_csv('beta_max.txt',header=None)
data_2_max= pd.read_csv('lam1_max.txt',header=None)
data_3_max = pd.read_csv('lam2_max.txt',header=None)
data_4_max=pd.read_csv('lam3_max.txt',header=None)

data_max=data_max.rename(columns={0:'shape 1'})
data_2_max=data_2_max.rename(columns={0:'shape 2'})
data_3_max=data_3_max.rename(columns={0:'shape 3'})
data_4_max=data_4_max.rename(columns={0:'shape 4'})
df_max=pd.concat([data_max,data_2_max,data_3_max,data_4_max],axis=1,join='inner')
plt.figure(figsize=[17,18])
df_max.boxplot(return_type='axes',fontsize=25)
plt.ylabel('max hydrogen concentration / ppm',fontsize=25)
plt.rc('xtick', labelsize=25) 
plt.rc('ytick', labelsize=25) 
plt.savefig('max_boxplot.png', bbox_inches='tight')
