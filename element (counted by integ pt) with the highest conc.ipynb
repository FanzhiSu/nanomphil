# %%
import numpy as np

beta=np.loadtxt('/home/clark/Desktop/beta_max_index_in_element.txt')
lam1=np.loadtxt('/home/clark/Desktop/lam1_max_index_in_element.txt')
lam2=np.loadtxt('/home/clark/Desktop/lam2_max_index_in_element.txt')
lam3=np.loadtxt('/home/clark/Desktop/lam3_max_index_in_element.txt')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-a1f689b03f5a> in <module>
#       1 import numpy as np
#       2
# ----> 3 beta=np.loadtxt('/home/clark/Desktop/beta_max_index_in_element.txt')
#       4 lam1=np.loadtxt('/home/clark/Desktop/lam1_max_index_in_element.txt')
#       5 lam2=np.loadtxt('/home/clark/Desktop/lam2_max_index_in_element.txt')
#
# ~/.local/lib/python3.8/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1063             fname = os_fspath(fname)
#    1064         if _is_string_like(fname):
# -> 1065             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1066             fencoding = getattr(fh, 'encoding', 'latin1')
#    1067             fh = iter(fh)
#
# ...

# %%
from collections import Counter
from itertools import repeat, chain
print (list(chain.from_iterable(repeat(i, c) for i,c in Counter(beta).most_common())))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9fe603125e5a> in <module>
#       1 from collections import Counter
#       2 from itertools import repeat, chain
# ----> 3 print (list(chain.from_iterable(repeat(i, c) for i,c in Counter(beta).most_common())))
#
# NameError: name 'beta' is not defined

# %%
len(beta)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-92e2944fc1e5> in <module>
# ----> 1 len(beta)
#
# NameError: name 'beta' is not defined

# %%
Counter(beta)
# Out:
# Counter({1062.0: 18,
#          1710.0: 1,
#          812.0: 15,
#          1085.0: 9,
#          745.0: 1,
#          1657.0: 3,
#          726.0: 1,
#          1098.0: 19,
#          1223.0: 1,
#          138.0: 3,
#          776.0: 11,
#          920.0: 16,
#          1074.0: 10,
#          1063.0: 19,
#          653.0: 14,
#          643.0: 11,
#          803.0: 4,
#          954.0: 19,
#          782.0: 5,
#          142.0: 1,
#          1100.0: 13,
#          1086.0: 13,
#          772.0: 1,
#          655.0: 13,
#          665.0: 11,
#          934.0: 5,
#          632.0: 6,
#          1357.0: 2,
#          72.0: 1,
#          1087.0: 10,
#          654.0: 19,
#          1290.0: 1,
#          1646.0: 3,
#          631.0: 17,
#          1064.0: 3,
#          1665.0: 1,
#          139.0: 3,
#          790.0: 7,
#          1668.0: 4,
#          1075.0: 12,
#          644.0: 14,
#          775.0: 12,
#          667.0: 22,
#          656.0: 14,
#          1090.0: 1,
# ...

# %%
print (list(chain.from_iterable(repeat(i, c) for i,c in Counter(lam1).most_common())))
# Out:
# [788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 930.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 799.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785
# ...

# %%
Counter(lam1[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d3224439fd9c> in <module>
# ----> 1 Counter(lam1[0])
#
# NameError: name 'Counter' is not defined

# %%
print (list(chain.from_iterable(repeat(i, c) for i,c in Counter(lam2).most_common())))
# Out:
# [941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 785.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788.0, 788
# ...

# %%
Counter(lam2)
# Out:
# Counter({929.0: 34,
#          1710.0: 1,
#          801.0: 25,
#          941.0: 45,
#          769.0: 2,
#          1657.0: 4,
#          762.0: 13,
#          945.0: 23,
#          1646.0: 2,
#          1223.0: 1,
#          788.0: 42,
#          789.0: 20,
#          933.0: 21,
#          1652.0: 6,
#          918.0: 8,
#          1508.0: 1,
#          796.0: 21,
#          775.0: 9,
#          906.0: 8,
#          803.0: 3,
#          797.0: 29,
#          784.0: 17,
#          967.0: 13,
#          942.0: 7,
#          761.0: 1,
#          798.0: 4,
#          823.0: 17,
#          1213.0: 1,
#          72.0: 1,
#          919.0: 5,
#          782.0: 3,
#          1290.0: 1,
#          1645.0: 3,
#          907.0: 14,
#          1665.0: 2,
#          804.0: 1,
#          1668.0: 5,
#          928.0: 21,
#          800.0: 42,
#          793.0: 3,
#          795.0: 7,
#          785.0: 44,
#          822.0: 6,
#          944.0: 37,
#          732.0: 4,
#          853.0: 3,
# ...

# %%
print (list(chain.from_iterable(repeat(i, c) for i,c in Counter(lam3).most_common())))
# Out:
# [801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 801.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 940.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 941.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932.0, 932
# ...

# %%
Counter(lam3)
# Out:
# Counter({906.0: 10,
#          1710.0: 1,
#          800.0: 23,
#          940.0: 37,
#          745.0: 1,
#          1657.0: 3,
#          62.0: 4,
#          945.0: 34,
#          1646.0: 2,
#          1223.0: 1,
#          795.0: 6,
#          789.0: 28,
#          933.0: 27,
#          875.0: 3,
#          1218.0: 11,
#          1507.0: 1,
#          796.0: 25,
#          775.0: 7,
#          918.0: 6,
#          803.0: 3,
#          966.0: 11,
#          784.0: 29,
#          801.0: 48,
#          967.0: 10,
#          941.0: 35,
#          761.0: 1,
#          822.0: 9,
#          499.0: 9,
#          785.0: 30,
#          782.0: 3,
#          1645.0: 4,
#          783.0: 5,
#          907.0: 11,
#          1665.0: 2,
#          1081.0: 2,
#          1668.0: 5,
#          797.0: 32,
#          928.0: 28,
#          788.0: 30,
#          929.0: 31,
#          810.0: 3,
#          793.0: 2,
#          927.0: 3,
#          1087.0: 6,
#          732.0: 2,
#          853.0: 2,
# ...

# %%
n_lam1= 24
n_lam2=40
n_lam3=56
n_beta=64
n=1728
v_lam1=n_lam1/n
v_beta=n_beta/n
v_lam3=n_lam3/n
v_lam2=n_lam2/n

# %%
print('lam1: '+ str(round(v_lam1,4)*100)+'%')
print('beta: '+str(round(v_beta,4)*100)+'%')
print('lam3: '+str(round(v_lam3,4)*100)+'%')
print('lam2: '+str(round(v_lam2,4)*100)+'%')
# Out:
# lam1: 1.39%
# beta: 3.6999999999999997%
# lam3: 3.2399999999999998%
# lam2: 2.31%

# %%
round(v_lam1,3)
# Out:
# 0.014
